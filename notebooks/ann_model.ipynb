# %%
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import *

# %%
X_train = pd.read_csv('../data/X_smote.csv')
y_train = pd.read_csv('../data/y_smote.csv')

X_test = pd.read_csv('../data/X_test.csv')
y_test = pd.read_csv('../data/y_test.csv')

y_train = y_train.values.ravel()
y_test = y_test.values.ravel()

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input

model = Sequential([

    Input(shape=(X_train.shape[1],)),

    Dense(
        64,
        activation='relu'
    ),

    Dropout(0.3),

    Dense(
        32,
        activation='relu'
    ),

    Dropout(0.2),

    Dense(
        1,
        activation='sigmoid'
    )
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                      ┃ Output Shape             ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                   │ (None, 64)               │         2,176 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)               │ (None, 64)               │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_4 (Dense)                   │ (None, 32)               │         2,080 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)               │ (None, 32)               │             0 │
# ├───────────────────────────────────┼──────────────────────────┼───────────────┤
# │ dense_5 (Dense)                   │ (None, 1)                │            33 │
# └───────────────────────────────────┴──────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=50,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6810 - loss: 0.5843 - val_accuracy: 0.7899 - val_loss: 0.5224
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.7926 - loss: 0.4705 - val_accuracy: 0.8076 - val_loss: 0.4541
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8263 - loss: 0.4157 - val_accuracy: 0.8532 - val_loss: 0.3400
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8332 - loss: 0.4037 - val_accuracy: 0.8354 - val_loss: 0.3598
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8389 - loss: 0.3871 - val_accuracy: 0.8582 - val_loss: 0.3119
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8459 - loss: 0.3663 - val_accuracy: 0.8532 - val_loss: 0.3219
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8548 - loss: 0.3467 - val_accuracy: 0.8709 - val_loss: 0.2764
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8592 - loss: 0.3537 - val_accuracy: 0.8684 - val_loss: 0.2675
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8586 - loss: 0.3273 - val_accuracy: 0.8684 - val_loss: 0.2751
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8694 - loss: 0.3404 - val_accuracy: 0.8658 - val_loss: 0.2757
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8687 - loss: 0.3193 - val_accuracy: 0.8684 - val_loss: 0.2756
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8599 - loss: 0.3322 - val_accuracy: 0.8734 - val_loss: 0.2537
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8662 - loss: 0.3159 - val_accuracy: 0.8759 - val_loss: 0.2354
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8649 - loss: 0.3174 - val_accuracy: 0.8734 - val_loss: 0.2462
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8789 - loss: 0.3112 - val_accuracy: 0.8658 - val_loss: 0.2624
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8859 - loss: 0.2852 - val_accuracy: 0.8759 - val_loss: 0.2402
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8738 - loss: 0.2914 - val_accuracy: 0.8810 - val_loss: 0.2363
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8852 - loss: 0.2875 - val_accuracy: 0.8886 - val_loss: 0.2252
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8897 - loss: 0.2795 - val_accuracy: 0.8886 - val_loss: 0.2157
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8859 - loss: 0.2738 - val_accuracy: 0.8911 - val_loss: 0.2169
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8852 - loss: 0.2777 - val_accuracy: 0.8886 - val_loss: 0.2257
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8871 - loss: 0.2761 - val_accuracy: 0.8911 - val_loss: 0.2010
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8802 - loss: 0.2748 - val_accuracy: 0.8911 - val_loss: 0.2089
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8897 - loss: 0.2598 - val_accuracy: 0.8886 - val_loss: 0.2160
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8954 - loss: 0.2606 - val_accuracy: 0.9038 - val_loss: 0.1892
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8998 - loss: 0.2390 - val_accuracy: 0.8886 - val_loss: 0.2101
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9017 - loss: 0.2522 - val_accuracy: 0.9089 - val_loss: 0.1893
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9004 - loss: 0.2453 - val_accuracy: 0.9063 - val_loss: 0.1752
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8954 - loss: 0.2518 - val_accuracy: 0.9165 - val_loss: 0.1679
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9169 - loss: 0.2271 - val_accuracy: 0.9063 - val_loss: 0.1750
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9004 - loss: 0.2360 - val_accuracy: 0.9089 - val_loss: 0.1748
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9081 - loss: 0.2335 - val_accuracy: 0.8987 - val_loss: 0.2036
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9150 - loss: 0.2234 - val_accuracy: 0.9215 - val_loss: 0.1644
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9049 - loss: 0.2208 - val_accuracy: 0.9114 - val_loss: 0.1724
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9062 - loss: 0.2245 - val_accuracy: 0.9089 - val_loss: 0.1713
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9144 - loss: 0.2273 - val_accuracy: 0.9215 - val_loss: 0.1634
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9062 - loss: 0.2129 - val_accuracy: 0.9215 - val_loss: 0.1629
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9150 - loss: 0.2152 - val_accuracy: 0.9190 - val_loss: 0.1605
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9188 - loss: 0.2113 - val_accuracy: 0.9215 - val_loss: 0.1650
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9150 - loss: 0.2017 - val_accuracy: 0.9215 - val_loss: 0.1609
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9207 - loss: 0.2122 - val_accuracy: 0.9165 - val_loss: 0.1662
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9131 - loss: 0.2135 - val_accuracy: 0.9241 - val_loss: 0.1646
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9245 - loss: 0.2006 - val_accuracy: 0.9342 - val_loss: 0.1506
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9188 - loss: 0.2082 - val_accuracy: 0.9316 - val_loss: 0.1492
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9283 - loss: 0.2038 - val_accuracy: 0.9291 - val_loss: 0.1463
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9195 - loss: 0.1966 - val_accuracy: 0.9392 - val_loss: 0.1423
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9296 - loss: 0.1883 - val_accuracy: 0.9367 - val_loss: 0.1328
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9233 - loss: 0.1869 - val_accuracy: 0.9266 - val_loss: 0.1424
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9315 - loss: 0.1810 - val_accuracy: 0.9316 - val_loss: 0.1401
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9226 - loss: 0.1836 - val_accuracy: 0.9443 - val_loss: 0.1351

# %%
y_prob = model.predict(X_test)

y_pred = (
    y_prob > 0.5
).astype(int)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
print(
    "Accuracy:",
    accuracy_score(y_test,y_pred)
)

print(
    "Precision:",
    precision_score(y_test,y_pred)
)

print(
    "Recall:",
    recall_score(y_test,y_pred)
)

print(
    "F1:",
    f1_score(y_test,y_pred)
)

print(
    "ROC AUC:",
    roc_auc_score(y_test,y_prob)
)
# Out:
# Accuracy: 0.8401360544217688
# Precision: 0.5
# Recall: 0.5106382978723404
# F1: 0.5052631578947369
# ROC AUC: 0.7286587992075114
